# %%
#!pip uninstall huetracer -y
#!pip install huetracer
import scanpy as sc
import matplotlib.pyplot as plt
import seaborn as sns
import os
import random
import numpy as np
import pandas as pd
import huetracer
import scvi
import gc
import math
import warnings

pd.set_option('display.max_columns', None)
sc.set_figure_params(figsize=[10,10],dpi=100)

warnings.filterwarnings('ignore', category=pd.errors.PerformanceWarning)

# %config InlineBackend.print_figure_kwargs={"facecolor": "w"}
# %config InlineBackend.figure_format="retina"

scvi.settings.seed = 0
SEED = 42

np.random.seed(SEED)
random.seed(SEED)
# Out:
# Seed set to 0

# %%
### parameters to be input
#SAMPLE_NAME = 'G1'
SAMPLE_NAME = 'FFPE9'
lib_id = SAMPLE_NAME # list(sp_adata.uns['spatial'].keys())[0]

path = os.path.expanduser("~")+"/Desktop/space/GCTB_bin2cell"
save_path_for_today = os.path.expanduser("~")+"/tmp/outputs/250610_" + SAMPLE_NAME
visium_path = "/Volumes/Public/data/giant_cell_tumor_sue/visium_HD/"
source_image_path = visium_path + "image/" + SAMPLE_NAME + ".tif"
expression_path = visium_path + SAMPLE_NAME + "/outs/binned_outputs/square_002um"
### optional 8/16 um binned dataset
expression_path_8um = visium_path + SAMPLE_NAME + "/outs/binned_outputs/square_008um"
expression_path_16um = visium_path + SAMPLE_NAME + "/outs/binned_outputs/square_016um"
###

# single cell transcriptome dataset (10X Chromium)
sc_adata_SK286_01_dir = visium_path + '../chromium/SK286_01/count/sample_filtered_feature_bc_matrix'
sc_adata_SK286_04_dir = visium_path + '../chromium/SK286_04/count/sample_filtered_feature_bc_matrix'
sc_adata_SK318_06_dir = visium_path + '../chromium/GCTB_06/count/sample_filtered_feature_bc_matrix'
sc_adata_SK318_07_dir = visium_path + '../chromium/GCTB_07/count/sample_filtered_feature_bc_matrix'
sc_adata_SK318_08_dir = visium_path + '../chromium/GCTB_08/count/sample_filtered_feature_bc_matrix'
sc_adata_SK318_09_dir = visium_path + '../chromium/GCTB_09/count/sample_filtered_feature_bc_matrix'
sc_adata_SK318_11_dir = visium_path + '../chromium/GCTB_11/count/sample_filtered_feature_bc_matrix'
sc_adata_SK318_12_dir = visium_path + '../chromium/GCTB_12/count/sample_filtered_feature_bc_matrix'

# area to be analyzed
# ## GCTB spatial G1, FFPE9
mask_large_x1, mask_large_x2, mask_large_y1, mask_large_y2 = 450, 1950, 250, 1750

# List of target gene names
target_genes = [
    'TNFSF11', 'LIF', 'TNFRSF11A', 'LIFR',
    'CTSK', 'CTSB', 'LMNB1', 'MEGF10',
    'MMP9', 'MMP13', 'SPP1', 'GRN',
    'NOTCH3', 'SDC2', 'TIMP1', 'SPARC',
    'ACP5'
    # Add more genes here if needed
]


# setting for filenames
label_image_filename = "he_labels_image.pdf"
h5ad_filename = SAMPLE_NAME + "_b2c.h5ad"
h5ad_full_filename = SAMPLE_NAME + "_2um.h5ad"
h5ad_predicted_full_filename = SAMPLE_NAME + "_nucleus_predicted.h5ad"
h5ad_sc_filtered_full_filename = SAMPLE_NAME + "_single_cell_filtered.h5ad"
h5ad_sc_microenvironment_full_filename = SAMPLE_NAME + "_single_cell_microenvironment.h5ad"
save_spatial_plot_path = os.path.join(save_path_for_today, "cropped_spatial_plot.svg")
save_svg_path = os.path.join(save_path_for_today, "spatial_salvage_labels.svg")
h5ad_save_path = os.path.join(save_path_for_today, h5ad_filename)
h5ad_full_save_path = os.path.join(save_path_for_today, h5ad_full_filename)
h5ad_predicted_full_save_path = os.path.join(save_path_for_today, h5ad_predicted_full_filename)
h5ad_sc_filtered_full_save_path = os.path.join(save_path_for_today, h5ad_sc_filtered_full_filename)
h5ad_microenvironment_full_save_path = os.path.join(save_path_for_today, h5ad_sc_microenvironment_full_filename)

os.chdir(path)
os.makedirs(save_path_for_today, exist_ok=True)

# %% [markdown]
# # Single cell transcriptome annotation

# %%
sc_adata = sc.read_10x_mtx(
    sc_adata_SK286_01_dir,  # 入力ディレクトリ
    var_names='gene_symbols', cache=True)
sc_adata.var_names_make_unique()  # this is unnecessary if using `var_names='gene_ids'` in `sc.read_10x_mtx`

sc_adata.var['MT'] = sc_adata.var_names.str.startswith('MT-')
sc.pp.calculate_qc_metrics(sc_adata, qc_vars=['MT'], percent_top=None, log1p=False, inplace=True)
sc.pl.highest_expr_genes(sc_adata, n_top=30)
sc.pl.violin(sc_adata, ['n_genes_by_counts', 'total_counts', 'pct_counts_MT'], jitter=0.4, multi_panel=True)
sc.pl.scatter(sc_adata, 'total_counts', 'n_genes_by_counts', color='pct_counts_MT', size=40)
sc.pl.scatter(sc_adata, x='total_counts', y='pct_counts_MT')
fig = plt.figure()
sns.displot(sc_adata.obs['pct_counts_MT'][sc_adata.obs['pct_counts_MT'] < 10], kde=False)
plt.show()

print('Total number of cells: {:d}'.format(sc_adata.n_obs))

# Filtering
sc.pp.filter_cells(sc_adata, min_genes=200)
sc.pp.filter_genes(sc_adata, min_cells=20)
print('Number of cells after low-quality cell filter: {:d}'.format(sc_adata.n_obs))

sc.pp.filter_cells(sc_adata, min_counts = 500)
sc.pp.filter_cells(sc_adata, max_counts = 100000)
print('Number of cells after count filter: {:d}'.format(sc_adata.n_obs))

sc_adata = sc_adata[sc_adata.obs['pct_counts_MT'] < 2]
print('Number of cells after MT filter: {:d}'.format(sc_adata.n_obs))

sc.pl.highest_expr_genes(sc_adata, n_top=30)
sc.pl.violin(sc_adata, ['n_genes_by_counts', 'total_counts', 'pct_counts_MT'], jitter=0.4, multi_panel=True)
sc.pl.scatter(sc_adata, 'total_counts', 'n_genes_by_counts', color='pct_counts_MT', size=40)
sc.pl.scatter(sc_adata, x='total_counts', y='pct_counts_MT')
fig = plt.figure()
sns.displot(sc_adata.obs['pct_counts_MT'][sc_adata.obs['pct_counts_MT'] < 3], kde=False)
plt.show()

sc_adata1 = sc_adata.copy()

# %%
sc_adata = sc.read_10x_mtx(
    sc_adata_SK286_04_dir,  # 入力ディレクトリ
    var_names='gene_symbols', cache=True)
sc_adata.var_names_make_unique()  # this is unnecessary if using `var_names='gene_ids'` in `sc.read_10x_mtx`

sc_adata.var['MT'] = sc_adata.var_names.str.startswith('MT-')
sc.pp.calculate_qc_metrics(sc_adata, qc_vars=['MT'], percent_top=None, log1p=False, inplace=True)
sc.pl.highest_expr_genes(sc_adata, n_top=30)
sc.pl.violin(sc_adata, ['n_genes_by_counts', 'total_counts', 'pct_counts_MT'], jitter=0.4, multi_panel=True)
sc.pl.scatter(sc_adata, 'total_counts', 'n_genes_by_counts', color='pct_counts_MT', size=40)
sc.pl.scatter(sc_adata, x='total_counts', y='pct_counts_MT')
fig = plt.figure()
sns.displot(sc_adata.obs['pct_counts_MT'][sc_adata.obs['pct_counts_MT'] < 10], kde=False)
plt.show()

print('Total number of cells: {:d}'.format(sc_adata.n_obs))

# Filtering
sc.pp.filter_cells(sc_adata, min_genes=200)
sc.pp.filter_genes(sc_adata, min_cells=20)
print('Number of cells after low-quality cell filter: {:d}'.format(sc_adata.n_obs))

sc.pp.filter_cells(sc_adata, min_counts = 500)
sc.pp.filter_cells(sc_adata, max_counts = 100000)
print('Number of cells after count filter: {:d}'.format(sc_adata.n_obs))

sc_adata = sc_adata[sc_adata.obs['pct_counts_MT'] < 2]
print('Number of cells after MT filter: {:d}'.format(sc_adata.n_obs))

sc.pl.highest_expr_genes(sc_adata, n_top=30)
sc.pl.violin(sc_adata, ['n_genes_by_counts', 'total_counts', 'pct_counts_MT'], jitter=0.4, multi_panel=True)
sc.pl.scatter(sc_adata, 'total_counts', 'n_genes_by_counts', color='pct_counts_MT', size=40)
sc.pl.scatter(sc_adata, x='total_counts', y='pct_counts_MT')
fig = plt.figure()
sns.displot(sc_adata.obs['pct_counts_MT'][sc_adata.obs['pct_counts_MT'] < 3], kde=False)
plt.show()

sc_adata2 = sc_adata.copy()

# %%
sc_adata = sc.read_10x_mtx(
    sc_adata_SK318_06_dir,  # 入力ディレクトリ
    var_names='gene_symbols', cache=True)
sc_adata.var_names_make_unique()  # this is unnecessary if using `var_names='gene_ids'` in `sc.read_10x_mtx`

sc_adata.var['MT'] = sc_adata.var_names.str.startswith('MT-')
sc.pp.calculate_qc_metrics(sc_adata, qc_vars=['MT'], percent_top=None, log1p=False, inplace=True)
sc.pl.highest_expr_genes(sc_adata, n_top=30)
sc.pl.violin(sc_adata, ['n_genes_by_counts', 'total_counts', 'pct_counts_MT'], jitter=0.4, multi_panel=True)
sc.pl.scatter(sc_adata, 'total_counts', 'n_genes_by_counts', color='pct_counts_MT', size=40)
sc.pl.scatter(sc_adata, x='total_counts', y='pct_counts_MT')
fig = plt.figure()
sns.displot(sc_adata.obs['pct_counts_MT'][sc_adata.obs['pct_counts_MT'] < 10], kde=False)
plt.show()

print('Total number of cells: {:d}'.format(sc_adata.n_obs))

# Filtering
sc.pp.filter_cells(sc_adata, min_genes=200)
sc.pp.filter_genes(sc_adata, min_cells=20)
print('Number of cells after low-quality cell filter: {:d}'.format(sc_adata.n_obs))

sc.pp.filter_cells(sc_adata, min_counts = 500)
sc.pp.filter_cells(sc_adata, max_counts = 100000)
print('Number of cells after count filter: {:d}'.format(sc_adata.n_obs))

sc_adata = sc_adata[sc_adata.obs['pct_counts_MT'] < 2]
print('Number of cells after MT filter: {:d}'.format(sc_adata.n_obs))

sc.pl.highest_expr_genes(sc_adata, n_top=30)
sc.pl.violin(sc_adata, ['n_genes_by_counts', 'total_counts', 'pct_counts_MT'], jitter=0.4, multi_panel=True)
sc.pl.scatter(sc_adata, 'total_counts', 'n_genes_by_counts', color='pct_counts_MT', size=40)
sc.pl.scatter(sc_adata, x='total_counts', y='pct_counts_MT')
fig = plt.figure()
sns.displot(sc_adata.obs['pct_counts_MT'][sc_adata.obs['pct_counts_MT'] < 3], kde=False)
plt.show()

sc_adata3 = sc_adata.copy()

# %%
sc_adata = sc.read_10x_mtx(
    sc_adata_SK318_07_dir,  # 入力ディレクトリ
    var_names='gene_symbols', cache=True)
sc_adata.var_names_make_unique()  # this is unnecessary if using `var_names='gene_ids'` in `sc.read_10x_mtx`

sc_adata.var['MT'] = sc_adata.var_names.str.startswith('MT-')
sc.pp.calculate_qc_metrics(sc_adata, qc_vars=['MT'], percent_top=None, log1p=False, inplace=True)
sc.pl.highest_expr_genes(sc_adata, n_top=30)
sc.pl.violin(sc_adata, ['n_genes_by_counts', 'total_counts', 'pct_counts_MT'], jitter=0.4, multi_panel=True)
sc.pl.scatter(sc_adata, 'total_counts', 'n_genes_by_counts', color='pct_counts_MT', size=40)
sc.pl.scatter(sc_adata, x='total_counts', y='pct_counts_MT')
fig = plt.figure()
sns.displot(sc_adata.obs['pct_counts_MT'][sc_adata.obs['pct_counts_MT'] < 10], kde=False)
plt.show()

print('Total number of cells: {:d}'.format(sc_adata.n_obs))

# Filtering
sc.pp.filter_cells(sc_adata, min_genes=200)
sc.pp.filter_genes(sc_adata, min_cells=20)
print('Number of cells after low-quality cell filter: {:d}'.format(sc_adata.n_obs))

sc.pp.filter_cells(sc_adata, min_counts = 500)
sc.pp.filter_cells(sc_adata, max_counts = 100000)
print('Number of cells after count filter: {:d}'.format(sc_adata.n_obs))

sc_adata = sc_adata[sc_adata.obs['pct_counts_MT'] < 2]
print('Number of cells after MT filter: {:d}'.format(sc_adata.n_obs))

sc.pl.highest_expr_genes(sc_adata, n_top=30)
sc.pl.violin(sc_adata, ['n_genes_by_counts', 'total_counts', 'pct_counts_MT'], jitter=0.4, multi_panel=True)
sc.pl.scatter(sc_adata, 'total_counts', 'n_genes_by_counts', color='pct_counts_MT', size=40)
sc.pl.scatter(sc_adata, x='total_counts', y='pct_counts_MT')
fig = plt.figure()
sns.displot(sc_adata.obs['pct_counts_MT'][sc_adata.obs['pct_counts_MT'] < 3], kde=False)
plt.show()

sc_adata4 = sc_adata.copy()

# %%
sc_adata = sc.read_10x_mtx(
    sc_adata_SK318_08_dir,  # 入力ディレクトリ
    var_names='gene_symbols', cache=True)
sc_adata.var_names_make_unique()  # this is unnecessary if using `var_names='gene_ids'` in `sc.read_10x_mtx`

sc_adata.var['MT'] = sc_adata.var_names.str.startswith('MT-')
sc.pp.calculate_qc_metrics(sc_adata, qc_vars=['MT'], percent_top=None, log1p=False, inplace=True)
sc.pl.highest_expr_genes(sc_adata, n_top=30)
sc.pl.violin(sc_adata, ['n_genes_by_counts', 'total_counts', 'pct_counts_MT'], jitter=0.4, multi_panel=True)
sc.pl.scatter(sc_adata, 'total_counts', 'n_genes_by_counts', color='pct_counts_MT', size=40)
sc.pl.scatter(sc_adata, x='total_counts', y='pct_counts_MT')
fig = plt.figure()
sns.displot(sc_adata.obs['pct_counts_MT'][sc_adata.obs['pct_counts_MT'] < 10], kde=False)
plt.show()

print('Total number of cells: {:d}'.format(sc_adata.n_obs))

# Filtering
sc.pp.filter_cells(sc_adata, min_genes=200)
sc.pp.filter_genes(sc_adata, min_cells=20)
print('Number of cells after low-quality cell filter: {:d}'.format(sc_adata.n_obs))

sc.pp.filter_cells(sc_adata, min_counts = 500)
sc.pp.filter_cells(sc_adata, max_counts = 100000)
print('Number of cells after count filter: {:d}'.format(sc_adata.n_obs))

sc_adata = sc_adata[sc_adata.obs['pct_counts_MT'] < 2]
print('Number of cells after MT filter: {:d}'.format(sc_adata.n_obs))

sc.pl.highest_expr_genes(sc_adata, n_top=30)
sc.pl.violin(sc_adata, ['n_genes_by_counts', 'total_counts', 'pct_counts_MT'], jitter=0.4, multi_panel=True)
sc.pl.scatter(sc_adata, 'total_counts', 'n_genes_by_counts', color='pct_counts_MT', size=40)
sc.pl.scatter(sc_adata, x='total_counts', y='pct_counts_MT')
fig = plt.figure()
sns.displot(sc_adata.obs['pct_counts_MT'][sc_adata.obs['pct_counts_MT'] < 3], kde=False)
plt.show()

sc_adata5 = sc_adata.copy()

# %%
sc_adata = sc.read_10x_mtx(
    sc_adata_SK318_09_dir,  # 入力ディレクトリ
    var_names='gene_symbols', cache=True)
sc_adata.var_names_make_unique()  # this is unnecessary if using `var_names='gene_ids'` in `sc.read_10x_mtx`

sc_adata.var['MT'] = sc_adata.var_names.str.startswith('MT-')
sc.pp.calculate_qc_metrics(sc_adata, qc_vars=['MT'], percent_top=None, log1p=False, inplace=True)
sc.pl.highest_expr_genes(sc_adata, n_top=30)
sc.pl.violin(sc_adata, ['n_genes_by_counts', 'total_counts', 'pct_counts_MT'], jitter=0.4, multi_panel=True)
sc.pl.scatter(sc_adata, 'total_counts', 'n_genes_by_counts', color='pct_counts_MT', size=40)
sc.pl.scatter(sc_adata, x='total_counts', y='pct_counts_MT')
fig = plt.figure()
sns.displot(sc_adata.obs['pct_counts_MT'][sc_adata.obs['pct_counts_MT'] < 10], kde=False)
plt.show()

print('Total number of cells: {:d}'.format(sc_adata.n_obs))

# Filtering
sc.pp.filter_cells(sc_adata, min_genes=200)
sc.pp.filter_genes(sc_adata, min_cells=20)
print('Number of cells after low-quality cell filter: {:d}'.format(sc_adata.n_obs))

sc.pp.filter_cells(sc_adata, min_counts = 500)
sc.pp.filter_cells(sc_adata, max_counts = 100000)
print('Number of cells after count filter: {:d}'.format(sc_adata.n_obs))

sc_adata = sc_adata[sc_adata.obs['pct_counts_MT'] < 2]
print('Number of cells after MT filter: {:d}'.format(sc_adata.n_obs))

sc.pl.highest_expr_genes(sc_adata, n_top=30)
sc.pl.violin(sc_adata, ['n_genes_by_counts', 'total_counts', 'pct_counts_MT'], jitter=0.4, multi_panel=True)
sc.pl.scatter(sc_adata, 'total_counts', 'n_genes_by_counts', color='pct_counts_MT', size=40)
sc.pl.scatter(sc_adata, x='total_counts', y='pct_counts_MT')
fig = plt.figure()
sns.displot(sc_adata.obs['pct_counts_MT'][sc_adata.obs['pct_counts_MT'] < 3], kde=False)
plt.show()

sc_adata6 = sc_adata.copy()

# %%
sc_adata = sc.read_10x_mtx(
    sc_adata_SK318_11_dir,  # 入力ディレクトリ
    var_names='gene_symbols', cache=True)
sc_adata.var_names_make_unique()  # this is unnecessary if using `var_names='gene_ids'` in `sc.read_10x_mtx`

sc_adata.var['MT'] = sc_adata.var_names.str.startswith('MT-')
sc.pp.calculate_qc_metrics(sc_adata, qc_vars=['MT'], percent_top=None, log1p=False, inplace=True)
sc.pl.highest_expr_genes(sc_adata, n_top=30)
sc.pl.violin(sc_adata, ['n_genes_by_counts', 'total_counts', 'pct_counts_MT'], jitter=0.4, multi_panel=True)
sc.pl.scatter(sc_adata, 'total_counts', 'n_genes_by_counts', color='pct_counts_MT', size=40)
sc.pl.scatter(sc_adata, x='total_counts', y='pct_counts_MT')
fig = plt.figure()
sns.displot(sc_adata.obs['pct_counts_MT'][sc_adata.obs['pct_counts_MT'] < 10], kde=False)
plt.show()

print('Total number of cells: {:d}'.format(sc_adata.n_obs))

# Filtering
sc.pp.filter_cells(sc_adata, min_genes=200)
sc.pp.filter_genes(sc_adata, min_cells=20)
print('Number of cells after low-quality cell filter: {:d}'.format(sc_adata.n_obs))

sc.pp.filter_cells(sc_adata, min_counts = 500)
sc.pp.filter_cells(sc_adata, max_counts = 100000)
print('Number of cells after count filter: {:d}'.format(sc_adata.n_obs))

sc_adata = sc_adata[sc_adata.obs['pct_counts_MT'] < 2]
print('Number of cells after MT filter: {:d}'.format(sc_adata.n_obs))

sc.pl.highest_expr_genes(sc_adata, n_top=30)
sc.pl.violin(sc_adata, ['n_genes_by_counts', 'total_counts', 'pct_counts_MT'], jitter=0.4, multi_panel=True)
sc.pl.scatter(sc_adata, 'total_counts', 'n_genes_by_counts', color='pct_counts_MT', size=40)
sc.pl.scatter(sc_adata, x='total_counts', y='pct_counts_MT')
fig = plt.figure()
sns.displot(sc_adata.obs['pct_counts_MT'][sc_adata.obs['pct_counts_MT'] < 3], kde=False)
plt.show()

sc_adata7 = sc_adata.copy()

# %%
sc_adata = sc.read_10x_mtx(
    sc_adata_SK318_12_dir,  # 入力ディレクトリ
    var_names='gene_symbols', cache=True)
sc_adata.var_names_make_unique()  # this is unnecessary if using `var_names='gene_ids'` in `sc.read_10x_mtx`

sc_adata.var['MT'] = sc_adata.var_names.str.startswith('MT-')
sc.pp.calculate_qc_metrics(sc_adata, qc_vars=['MT'], percent_top=None, log1p=False, inplace=True)
sc.pl.highest_expr_genes(sc_adata, n_top=30)
sc.pl.violin(sc_adata, ['n_genes_by_counts', 'total_counts', 'pct_counts_MT'], jitter=0.4, multi_panel=True)
sc.pl.scatter(sc_adata, 'total_counts', 'n_genes_by_counts', color='pct_counts_MT', size=40)
sc.pl.scatter(sc_adata, x='total_counts', y='pct_counts_MT')
fig = plt.figure()
sns.displot(sc_adata.obs['pct_counts_MT'][sc_adata.obs['pct_counts_MT'] < 10], kde=False)
plt.show()

print('Total number of cells: {:d}'.format(sc_adata.n_obs))

# Filtering
sc.pp.filter_cells(sc_adata, min_genes=200)
sc.pp.filter_genes(sc_adata, min_cells=20)
print('Number of cells after low-quality cell filter: {:d}'.format(sc_adata.n_obs))

sc.pp.filter_cells(sc_adata, min_counts = 500)
sc.pp.filter_cells(sc_adata, max_counts = 100000)
print('Number of cells after count filter: {:d}'.format(sc_adata.n_obs))

sc_adata = sc_adata[sc_adata.obs['pct_counts_MT'] < 2]
print('Number of cells after MT filter: {:d}'.format(sc_adata.n_obs))

sc.pl.highest_expr_genes(sc_adata, n_top=30)
sc.pl.violin(sc_adata, ['n_genes_by_counts', 'total_counts', 'pct_counts_MT'], jitter=0.4, multi_panel=True)
sc.pl.scatter(sc_adata, 'total_counts', 'n_genes_by_counts', color='pct_counts_MT', size=40)
sc.pl.scatter(sc_adata, x='total_counts', y='pct_counts_MT')
fig = plt.figure()
sns.displot(sc_adata.obs['pct_counts_MT'][sc_adata.obs['pct_counts_MT'] < 3], kde=False)
plt.show()

sc_adata8 = sc_adata.copy()

# %%
# sc_adata4 is a poor quality sample

# common_genes = set(sc_adata1.var_names) & set(sc_adata2.var_names) & set(sc_adata3.var_names) & set(sc_adata4.var_names) & set(sc_adata5.var_names) & set(sc_adata6.var_names) & set(sc_adata7.var_names) & set(sc_adata8.var_names)
common_genes = set(sc_adata1.var_names) & set(sc_adata2.var_names) & set(sc_adata3.var_names) & set(sc_adata5.var_names) & set(sc_adata6.var_names) & set(sc_adata7.var_names) & set(sc_adata8.var_names)
sc_adata1 = sc_adata1[:, list(common_genes)]
sc_adata2 = sc_adata2[:, list(common_genes)]
sc_adata3 = sc_adata3[:, list(common_genes)]
# sc_adata4 = sc_adata4[:, list(common_genes)]
sc_adata5 = sc_adata5[:, list(common_genes)]
sc_adata6 = sc_adata6[:, list(common_genes)]
sc_adata7 = sc_adata7[:, list(common_genes)]
sc_adata8 = sc_adata8[:, list(common_genes)]
# sc_adatas = [sc_adata1, sc_adata2, sc_adata3, sc_adata4, sc_adata5, sc_adata6, sc_adata7, sc_adata8]
sc_adatas = [sc_adata1, sc_adata2, sc_adata3, sc_adata5, sc_adata6, sc_adata7, sc_adata8]
sc_adata_merged = sc_adatas[0].concatenate(sc_adatas[1:], batch_key='batch')
del sc_adata1, sc_adata2, sc_adata3, sc_adata4, sc_adata5, sc_adata6, sc_adata7, sc_adata8
gc.collect()
# save raw count data
sc_adata_merged.layers["counts"] = sc_adata_merged.X.copy()
sc_adata_merged.raw = sc_adata_merged
# Out:
# /var/folders/4d/y2tgzy191n37wnz840jkr6980000gp/T/ipykernel_16666/3787784722.py:15: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   sc_adata_merged = sc_adatas[0].concatenate(sc_adatas[1:], batch_key='batch')

# %%
# reset with raw count data
# Harmonyのランダム性排除のためkmeansからAgglomerativeClusteringにclustering手法を変更

np.random.seed(SEED)
random.seed(SEED)
sc_adata_merged.X = sc_adata_merged.raw.X.copy()
sc_adata_merged.var = sc_adata_merged.raw.var.copy()
sc.pp.normalize_total(sc_adata_merged, target_sum=1e4)
sc.pp.log1p(sc_adata_merged)
sc.pp.highly_variable_genes(sc_adata_merged, flavor = 'seurat_v3', n_top_genes=2000,
                            layer = "counts", batch_key="batch", subset = False)
hvg_genes = sc_adata_merged.var_names[sc_adata_merged.var['highly_variable']].tolist()
sc.tl.pca(sc_adata_merged, svd_solver='arpack', mask_var="highly_variable", n_comps=30, random_state=SEED)
ho = huetracer.run_harmony(sc_adata_merged.obsm['X_pca'], sc_adata_merged.obs, 'batch',random_state=SEED)
sc_adata_merged.obsm['X_pca_harmony'] = ho.Z_corr.T
sc.pp.neighbors(sc_adata_merged, use_rep='X_pca_harmony', random_state=SEED)
sc.tl.umap(sc_adata_merged, min_dist=0.1, random_state=SEED)
sc.tl.leiden(sc_adata_merged, flavor="igraph", n_iterations=2, resolution=4, key_added='leiden', random_state=SEED)
sc_adata_merged.obs['leiden'] = sc_adata_merged.obs['leiden'].apply(lambda x: f"C{x}")
sc.pl.pca(sc_adata_merged, color='total_counts', components=['1,2', '2,3', '1,3'])
sc.pl.pca_variance_ratio(sc_adata_merged, log=True)
sc_adata_merged.var.sort_values("variances_norm",ascending=False).head(10)
sc.pl.umap(sc_adata_merged, color=['leiden', 'total_counts', 'batch'],use_raw=False)
sc.pl.umap(sc_adata_merged, color=['TRAC', 'COL1A1', 'CTSK'],use_raw=False)

# %%
sc.tl.dendrogram(sc_adata_merged, groupby='leiden')
sc.tl.rank_genes_groups(sc_adata_merged, 'leiden', method='wilcoxon', use_raw=False)
sc.pl.rank_genes_groups(sc_adata_merged, n_genes=25, sharey=False)

genes_df = pd.DataFrame(sc_adata_merged.uns['rank_genes_groups']['names'])
genes = genes_df.head(3).values.tolist()  # top 3 genes
genes = [item for sublist in genes for item in sublist]
genes = list(dict.fromkeys(genes))
genes = [str(g) for g in genes]
for i in range(0, len(genes), 4):
    subset_genes = [str(g) for g in genes[i:i + 4]]
    sc.pl.violin(
        sc_adata_merged,
        subset_genes,
        groupby='leiden',
        use_raw=False
    )

# %%
gene_array = np.array(sc_adata_merged.uns['rank_genes_groups']['names'].tolist())
gene_list = np.unique(gene_array[0:4,:].flatten())
sc.pl.umap(sc_adata_merged, color=gene_list, use_raw=False)

# %%
pd.DataFrame(sc_adata_merged.uns['rank_genes_groups']['names']).head(30)
# Out:
#          C0        C1        C2        C3        C4        C5        C6  \
# 0    COL1A1    COL6A1    COL3A1      MMP2      CCN2    COL3A1    COL1A2
# 1    COL3A1    COL6A2    COL6A1     LTBP3    COL1A2    COL7A1    COL1A1
# 2    COL1A2      GGT5      THY1     BGLAP    COL8A2     FBLN1     SPARC
# 3      ASPN    COL6A3    COL6A2     MXRA8     PTH1R    IGFBP7     PTH1R
# 4    COL5A1    NOTCH3    COL5A3    PCOLCE    COL1A1  SERPINA1    COL5A1
# 5     CILP2    ITGA11    PRSS23    COL6A2     PTPRS    COL5A2     PTPRS
# 6     THBS1       FN1    COL5A2    COL6A1     THBS1    CTHRC1    COL5A2
# 7    COL5A2    MEGF10   COL18A1     SFRP4      CHAD      CAV2    PCOLCE
# 8   TMEM119       C1S       BGN   COL16A1      FBN1       ID1      INSC
# 9      FBN1    COL5A2     PRRX1      ACAN    COL5A2     TAGLN     THBS2
# 10     MMP2       DCN      GGT5    COL3A1     PDGFD     VEGFC      CHAD
# 11    SPARC     ENPP2  CCDC102B    MEGF10     BGLAP    CAVIN1     MXRA8
# 12      BGN    COL1A1    NOTCH3       DCN     LTBP3      MYL9      MRC2
# 13    THBS2       C1R    IGFBP7   OLFML2A      ACAN      NID1     FGFR2
# 14     ACAN    COL5A1     FBLN7    LRRC15   TMEM119      SDC1    FKBP10
# 15   ITGBL1     FGFR1   COL16A1  SERPINF1    COL8A1    IGFBP4      IBSP
# 16    AEBP1     LTBP3     PRKG1   EMILIN1  ADAMTS10    IGFBP6       LUM
# 17   COL8A2     TIMP3     MXRA5     FBLN1       DCN     ITGA3   COL11A1
# 18     CCN2       LUM     POSTN      LSP1       TNC     MFAP5   CCDC194
# 19  COL16A1     SPARC    COL6A3     FGFR1     MXRA8      AGRN  SERPINF1
# 20   COL6A1     LTBP2   ADAMTS2      GJA1   TP53I11       ID3       DCN
# 21   COL8A1    COL3A1     FSTL1     FGFR2    ITGBL1      TPM2     THBS1
# 22    FSTL1    COL1A2    PDGFRB      ECM2      MMP2      CHPF   TP53I11
# 23     ECM2   EMILIN1     TGFB3       TNC     SPARC     SYTL1    CERCAM
# 24   LRRC15    LRRC15     FBLN1     KANK2    COL3A1     MFGE8    ITGA10
# 25  ADAMTS2   OLFML2A      NID2    NOTCH3     CILP2      DKK3    COL3A1
# 26     FGF7  SERPING1    COL1A1    COL8A2     LAMB2      TPM1   COL16A1
# 27    PRRX1      FAT1     LAMA4       LUM      INSC     MMP28   CREB3L1
# 28    FBLN1      CSF1   TMEM119      RGS3    LRRC15  SERPINE1  SERPINH1
# 29   COL6A2   COL16A1   OLFML2A    COL1A2     THBS2     LOXL2      GPC1
#
#           C7        C8       C9      C10       C11       C12       C13  \
# 0        DCN     PTH1R    LTBP3      FOS     BGLAP       DCN       DCN
# 1        FN1    ITGA10   NOTCH3     EGR1    LRRC15      NNMT    IGFBP7
# 2        LUM     LTBP3   MEGF10    DUSP1     PTH1R     TIMP3      LSP1
# 3      TIMP3     ITGB3  COL16A1      JUN       DCN     TIMP1     SYT12
# 4      ENPP2     PTPRS   COL6A1  COL16A1  SERPINF1       LUM      CHAD
# 5      PTGIS     FGFR1    FGFR1     CCN2      IBSP     PALLD     EPHA2
# 6     COL6A2     MXRA8   COL6A2     MRC2     C5AR2       FN1   COL10A1
# 7     COL6A3      MRC2  EMILIN1     FOSB   SLC29A1   CREB3L1     PTPRU
# 8     COL6A1   SLC29A1  OLFML2B   COL5A1     NCAM1      BMP3    S100A6
# 9       EMP1  ADAMTS10    MMP14   COL1A1  SERPINE2    MEGF10       ID1
# 10      IRX3       TNC    MXRA8   COL1A2       LUM     PTH1R       LUM
# 11       C1S    MEGF10   ITGA10   NOTCH3      FAT1   TP53I11       CD9
# 12    S100A6   TP53I11  OLFML2A   COL3A1    COL1A2      IBSP     CDH11
# 13   OLFML2A      FAT1   COL3A1   COL5A2   COL10A1     VCAM1     TIMP3
# 14      FZD7     UNC5B   CCDC80    AEBP1     SPARC      CSF1   S100A13
# 15      GGT5   EFCAB13      TNC   ITGA10     FGFR1     BMP8B  SERPINE1
# 16  TNFRSF19    FAM20C     MRC2     JUND    COL5A1    CAVIN1      PDPN
# 17     HTRA1     RUNX2   PCOLCE      TNC     F13A1     SPARC     LTBP3
# 18     ABHD2     CSPG4   COL6A3    LTBP3     PDGFD      CHAD     CADM1
# 19      LMNA     PDGFD    HTRA1  EMILIN1     PALLD     PDGFD      CAV2
# 20  SERPING1      FZD8   ITGA11    FGFR1     CDH11  SERPINE2    PLA2R1
# 21    OLFML3      CHAD    ITGB5    MMP13    ITGA11    CCDC80     KCNN4
# 22      GJA1     TIMP3    RUNX2   CCDC80   COL11A1    LRRC15   TP53I11
# 23   CREB3L1      SLPI   PDGFRB   PCOLCE  SERPING1       TNC     LTBP1
# 24      BMP2  SERPINF1   ANTXR1    RUNX2   TP53I11    OLFML3      ANKH
# 25    MEGF10     NCAM1    KANK2    THBS2     BMP8B       C1R      ACAN
# 26     BMP8B   CCDC194     CSF1   COL6A3    SCUBE1     FGFR1     MFGE8
# 27     SPARC     BMP8B   FAM20C   ITGA11    SPOCK1     PTGIS     MEF2A
# 28    LRRC15    COL1A2     SOX4     ENAH    COL5A2  SERPINF1     AHNAK
# 29    CTHRC1     SFRP4    MMP13    PTH1R     PDIA5    COL1A2     TGFB2
#
#         C14      C15       C16       C17       C18      C19     C20      C21  \
# 0    COL6A2     CCN2     PTH1R     MMP13      SLPI    FGFR1   STAB1     SAT1
# 1     MMP14    FSTL1      SLPI      SPP1     PTH1R    LTBP3   CD163    STAB1
# 2    COL6A1   COL6A1      CHAD     TIMP1   TP53I11  SLC29A1   TACC3   MS4A6A
# 3    NOTCH3    TAGLN   TP53I11      MRC2     BMP8B   CCDC80    CYBB     DAB2
# 4      THY1   ITGBL1     F13A1       TNC  SERPINE2      DCN   ITGAM  TNFAIP2
# 5   EMILIN1   COL8A2     PTPRS    COL6A3  SERPING1    TIMP3   CENPM    ADAP2
# 6      SDC2   COL3A1     CSPG4    COL1A1     ITGB3     NNMT   LAIR1    MS4A7
# 7     MMP13   COL6A2   CCDC194    PCOLCE     F13A1     MRC2   MPEG1    ITGAX
# 8    COL6A3   COL5A2      IBSP    COL1A2     SFRP4     CSF1  MS4A6A    CD163
# 9   OLFML2B    THBS1     ITGB3      IBSP  SERPINF1      TNC   DMXL2    FCGRT
# 10     GGT5    CALD1       CLU    COL5A1     MXRA8   NOTCH3  NUSAP1    HSPA6
# 11    HTRA1      BGN     LTBP1     BMP8A      FAT1     BST2    CDK1  SIGLEC1
# 12   TSPAN9   COL1A1     BMP8B   EMILIN1       CLU   MEGF10    H1-5    ABCA1
# 13   COL3A1   COL1A2  SERPINE2      ANKH      IBSP    MXRA8     HK3  ARHGAP4
# 14   CCDC80     FBN1  SERPINF1     TIMP3      FZD8     IRX3    CTSB  SLCO2B1
# 15    S1PR3     MYL9     SFRP4       MIA      CHAD     ANKH    CD14    ARAP1
# 16  COL16A1    CILP2     NCAM1       DCN   SLC29A1   FAM20C    C1QC    FCHO2
# 17    CEMIP    MXRA5     TIMP3      CSF1     NCAM1    PTH1R    GLUL     FGD2
# 18     GJA1   LRRC15     MFGE8     SPARC     PTPRS    FRMD6   KIF22    DOCK2
# 19     NID1     ACAN      FZD8      ACAN    OLFML3   OLFML3  CLEC7A    PLCB2
# 20   PDGFRB     CNN3    STEAP3     ENPP1       DCN    LTBP2    DAB2    ARRB2
# 21     CD99     THY1      BMP3      SDC2     CSPG4  EMILIN1   ESPL1    MYO9B
# 22   ANTXR1   COL5A1  ADAMTS10       ID1    MEGF10     LSP1   NCAPG   CSF2RA
# 23    TGFB3  TMEM119      CCN2   SLC29A1     BMP8A     SDC2   PHF19    CSF1R
# 24     SOX4   COL8A1      FAT1  SERPINH1     LTBP3    BGLAP     CIT   RASSF4
# 25  PCDHGC3    SPARC  SERPING1    OLFML3     TIMP3     EGR1   UHRF1  EHBP1L1
# 26   COL5A2     CCN1   EFCAB13     STMN3     BGLAP    UNC5B  NCAPG2    DMXL2
# 27    LTBP3     SDC1     PDGFD     FGFR1       FN1      LUM   ADAP2    CELF2
# 28     CSF1    FBLN1     MXRA8    CCDC80     FGFR1    FOXC1   CREG1     GLUL
# 29      MDK     ASPN     MMP16   CREB3L1      ANKH    HTRA1   MKI67    MERTK
#
#          C22       C23        C24       C25       C26      C27       C28  \
# 0     COL6A3       TNC       MMP9     CD163      AKNA    ALOX5    CORO1A
# 1        FN1      MRC2     TCIRG1     STAB1       EVL    GATA2      TRAC
# 2     SPOCK1    CCDC80       ACP5      CD14    CORO1A     AKNA      AKNA
# 3        DCN     PTH1R        CKB      C1QC     ITGAL     RGS2       B2M
# 4      LTBP2    NOTCH3       JDP2     MPEG1     CXCR4    CELF2      IL32
# 5      PTPRU       DCN      ANPEP      C1QA      TRAC  SLC45A3     IL2RG
# 6     CTHRC1     TIMP3       CTSK    MS4A6A      TMC8  CCDC88B       EVL
# 7       NNMT    MEGF10     SLC9B2      APOE     ACAP1     SRGN     ITGAL
# 8       ANKH      CSF1       MATK      C1QB     IL2RG     IRS2    TMSB4X
# 9       GGT5   SLC29A1      RUFY4     MS4A7     NLRC5    ITGAX     SYNE2
# 10  TNFRSF6B      IBSP     NFATC1   SLCO2B1    RASAL3     STX3     IKZF1
# 11      FHL2     PDGFD        CA2      CYBB   ARHGEF1    RSRP1     CXCR4
# 12     STMN3     LTBP3   SIGLEC15     ADAP2     IKZF1     ZEB2    RASAL3
# 13     TIMP1     FGFR1    SLC37A2     HSPA6     LENG8     MLPH   ARHGDIB
# 14    COL6A1  SERPING1     PHETA1      LGMN     SYNE2    ADRB2   ARHGEF1
# 15       BOC    OLFML3   ATP6V1B2   SIGLEC1     CELF2   ATP2A3      LCP1
# 16      IRX3      FAT1       CST3      PLTP   CCDC88C    TXNIP     ACAP1
# 17    S100A6  SERPINF1       WWC1      DAB2    ATP2A3    HPGDS     WIPF1
# 18     TIMP3     UNC5B      APOBR      MSR1     ITGA4   PLXNA4      TMC8
# 19   COL10A1    PCOLCE    COL27A1      MRC1    CLEC2D   SAMSN1     CELF2
# 20     KCNN4       C1S     SLC4A2    FCGR2A     STAT4     GALC      SRGN
# 21     MMP28     ITGB3     STRIP2    RNASE1   ARHGAP9   NBEAL2      CD44
# 22      NPC2     PTGIS       SPI1     ITGAX    RNF213   CSF2RB    ATP2A3
# 23     ENPP1       C1R        SRC  TMEM176B       B2M   PIK3CD    RNF213
# 24       PKM    LRRC15      FOSL2     FOLR2   ZFYVE28   STXBP5     NLRC5
# 25      CAV2     TIMP1  TNFRSF11A      PSAP      IL16    FOXP1    ADGRE5
# 26    IGFBP7     BMP8B       CD68    MS4A4A     PTPRC    VWA5A      IL16
# 27    LGALS1       FN1     NFKBIA    LILRB5  TRAF3IP3      BTK      SUN2
# 28     ABHD2    ITGA11      THOP1      CD74     SAMD3     TMC8     SASH3
# 29       LUM   EMILIN1       CSTB   TNFAIP2     WIPF1   MYO15B  ARHGAP30
#
#          C29        C30       C31      C32      C33      C34     C35      C36  \
# 0      LENG8      CCNL2       FOS    STAB1     SAT1     APOE   LMNB2   LRRC15
# 1    COL16A1       WSB1      FOSB    MS4A7    STAB1    GPNMB   KIFC1    TIMP2
# 2       TPM1      LENG8      EGR1    FCGRT    ITGAX     CTSD    TPX2  ANGPTL2
# 3       WSB1     PDLIM7     LENG8     DAB2    CD163     PSAP   LMNB1     ACAN
# 4      CCNL2      AEBP1     DUSP1   MS4A6A     GLUL     CTSB    TYMS   COL5A1
# 5    COL11A1      CEMIP   COL16A1    ADAP2     CTSL      FTL  NUSAP1    FBLN7
# 6       INSC     ARGLU1     CALD1    CD163    HMOX1    IFI30   CENPM   SLC7A2
# 7    IFITM10  HNRNPA2B1     CCNL2  SLCO2B1  TNFAIP2     LGMN   TOP2A    MMP13
# 8       LSP1       CLK1     AEBP1     SAT1     DAB2     CTSZ   MKI67     DKK3
# 9      CALD1    COL16A1   IFITM10  SIGLEC1    ADAP2     CTSL    ANLN   COL5A2
# 10     THBS2   ADAMTS14      JUND    HSPA6     FTH1     GLUL   KIF22    CEMIP
# 11  ADAMTS10      DDX17     THBS2    MPEG1     CTSB    ITGAX   SPC24    FSTL1
# 12    ARGLU1    DENND2B      TPM1    CSF1R      FTL     PLD3    PRC1     CCN4
# 13     AEBP1      CIRBP     NR4A1  SELENOP     TYMP     CD68   UHRF1     ALPL
# 14  KIAA1217     LUC7L3      MCL1  TNFAIP2    FCGRT     C1QC    SMC4    POSTN
# 15    PHLDB1    PPFIBP1      JUNB  ARHGAP4     SGK1    CD163   NCAPG    NPTX2
# 16      DDX5       BMP1      DDX5     MRC1     LGMN     C1QB  NCAPG2    FNDC1
# 17   FAM118A     ITGA10      KLF6     CD14  SLCO2B1     LIPA   TACC3     NTN1
# 18     CIRBP       VMP1      VCAN      MAF      NPL      GRN   CKAP4     MMP2
# 19   COL12A1       ENAH      ATF3     C1QA   MS4A6A     C1QA  IQGAP3   KCNJ15
# 20      CCN1       TIA1     NR4A2     CYBB    ABCA1    CREG1   TCF19      MGP
# 21     PRRX1       MDM4  CCDC102B    ABCA1  SIGLEC1   LHFPL2   FANCI  SPARCL1
# 22     FGFR1      PRKG1      WSB1     C1QC    MS4A7  SLC15A3     CIT      OGN
# 23     DDX17       DMWD   TSC22D3     APOE      HK3     CTSS   FOXM1      PAM
# 24      UACA       BDH2     ZFP36   FCGR2A   LILRB5     CD14   ZWINT   ORMDL3
# 25   ADAMTS2     GABBR1       JUN     C1QB    ARAP1     MSR1    CDK1    TGFB2
# 26      EPYC    ANKRD10    PLXDC1     FGD2     MSR1     TPP1    TMPO     CCN2
# 27      VCAN      CALD1    NFKBIZ    FOLR2    GPNMB    MPEG1   KIF23  PLEKHG4
# 28     HMCN1        MME    COL4A1   MS4A4A   CLEC7A    HMOX1  NCAPD2     ISM1
# 29    FKBP10      LUC7L      LMNA   RNASE1    FMNL2     CD74   FANCA    NTRK2
#
#          C37       C38       C39      C40       C41        C42      C43  \
# 0       C1QC       FOS     FCGRT     CD74    COL3A1      LOXL2   CCDC80
# 1       C1QA     DUSP1      APOE    CIITA    COL1A1     COL5A1     GJA1
# 2       C1QB     STAB1      C1QA      LYZ     MMP14   SERPINH1    THBS2
# 3       PSAP      CD14    MS4A6A   SAMHD1     AEBP1     COL6A3     MRC2
# 4       APOE      APOE     STAB1     TYMP    COL6A1      CKAP4    AEBP1
# 5       CD14      C1QA      C1QC     SPI1      BMP1     COL5A2     MMP2
# 6      CD163     CD163     MPEG1    ITGAX    COL6A2      FSTL1     EPYC
# 7       LGMN      C1QC     MS4A7   CSF2RA     CEMIP      TAGLN  COL11A1
# 8       CTSB   SELENOP     CD163    ITGB2    COL5A1        BGN     INSC
# 9      MPEG1     FCGRT      CD14    MPEG1    COL6A3     COL6A2     DLX5
# 10     FCGRT      LGMN      C1QB     CTSH     LOXL2     COL1A1   COL5A2
# 11  TMEM176B      SAT1   SELENOP     CYBB    COL1A2     COL6A1    FGFR2
# 12      CTSD      C1QB      CD74    CSF1R    COL5A2       TPM2    HTRA1
# 13      CTSL      CD74     ADAP2    IFI30     LAMB1     FKBP10    FRAS1
# 14      CTSZ    RNASE1      DAB2   CLEC7A   ADAMTS2      SPARC     BST2
# 15       FTL     ADAP2   SLCO2B1     FGL2     EDIL3      RRBP1     TPM1
# 16     STAB1      PSAP      LGMN     JAML       FAP     COL3A1    PDGFD
# 17      CD74      JUNB      PSAP    MYO1F     SFRP4       MYL9     DIO2
# 18      CYBB      DAB2   SIGLEC1   SLC8A1   COL16A1      PLOD2   COL3A1
# 19    MS4A6A     MPEG1     FOLR2     AOAH       MDK  TNFRSF12A      MME
# 20   SLCO2B1      PLTP      PLTP   LILRB2   DENND2B     COL5A3    PTH1R
# 21     IFI30    MS4A6A     HSPA6    ALOX5      MMP2       CD82     LMO7
# 22      PLD3     ZFP36     CSF1R    FMNL1   RNF144A     CERCAM   IGFBP7
# 23      PLTP   SLCO2B1  TMEM176B     ADA2  ADAMTS14    ADAMTS2   ANTXR1
# 24   SLC40A1      KLF6      CYBB    PLCB2      GGT5       THY1    EPHA2
# 25      SDC3  TMEM176B      MRC1    EFHD2      ENAH      CALD1     GPC1
# 26     FOLR2     MS4A7   TNFAIP2    ADAM8     PRRX1      THBS2     FBN1
# 27     GPNMB      FTH1      SAT1  EMILIN2       MME      TIMP1      CPE
# 28      CD68       JUN    MS4A4A  ARHGAP4    FKBP10      ITGA3    MXRA8
# 29     MS4A7      CYBB      CTSB   IL10RA      CHPF      P4HA2    CALD1
#
#           C44       C45        C46      C47       C48       C49       C50  \
# 0        MMP9    TCIRG1      ANPEP    CCNL2      APOE   COL12A1    COL1A1
# 1        ACP5      MMP9       SPI1    LENG8      C1QC       BGN    COL1A2
# 2        CTSK      ACP5      UHRF1  COL16A1      C1QA    COL8A1    COL5A1
# 3       ANPEP      CTSK       MMP9     DDX5      PSAP    LRRC15    COL5A2
# 4      SLC9B2      JDP2    SLC43A3     WSB1      CTSB     CDH11    COL3A1
# 5      TCIRG1   SLC37A2       PFN1      FOS      C1QB      NBL1     SPARC
# 6        JDP2     CSF1R       ENO1     EGR1      CD74     AEBP1    COL6A2
# 7     SLC37A2      SPI1       JDP2     ENAH    LAPTM5      FBN1  SERPINH1
# 8         CKB       CKB       TUFM    CALD1       FTL      VCAN    COL6A1
# 9    ATP6V1B2      CD84      EFHD2    RUNX2      CTSZ      SRPX     LOXL2
# 10     NFATC1      MATK     NFATC1   ARGLU1       B2M   TMEM119       BGN
# 11      RUFY4     CLCN7       CTSZ     CCN2      CD68   ADAMTS2     FSTL1
# 12   SIGLEC15     APOBR       MCM5  PPFIBP1      LGMN     SPARC    COL6A3
# 13       MATK  ATP6V1B2       EMP3   ITGA10       GRN     FNDC1     THBS2
# 14      CLCN7     ANPEP      WDFY4    DUSP1      PLD3     THBS2      RCN3
# 15     STRIP2       GRN      CSF1R   PDLIM7     IFI30  SERPINF1    CERCAM
# 16       CD68    NFATC1    SLC16A3  SLC12A4      CST3     MFAP2    PCOLCE
# 17      APOBR     ITGAX  TNFRSF11A    CIRBP      CTSD    COL5A1     CKAP4
# 18        GRN      NRP2     MAN2B1   PHLDB1     CD163   C1QTNF1    FKBP10
# 19      FOSL2      SAT1      CENPM    LUC7L      NPC2     MMP11     HSPG2
# 20        SRC     CYTH4      ZWINT     DMWD      CYBA      TPM1       FN1
# 21     PHETA1      PSAP     LAPTM5     FOSB      PLTP       DPT      CHPF
# 22     SLC4A2      TFEC       CLUH   GABBR1      CD14   COL11A1   EMILIN1
# 23    COL27A1      CD68       CYC1     RBM6       LYZ      COMP      FBN1
# 24       WWC1     FCGRT     SLC1A5    TTLL3    TMSB4X    ITGBL1      MMP2
# 25       SPI1     VASH1    SLC39A8     SHC1      TPP1       FN1      MRC2
# 26  TNFRSF11A    PHETA1     TCIRG1   SEC31A     ITGB2  SERPINH1     TIMP1
# 27       CST3    SLC9B2      VAMP8   LUC7L3    RNASE1    MARCKS     AEBP1
# 28      OSCAR       GNS      MKI67     KLF6  TMEM176B       C1R     FBLN1
# 29     MAP2K3    SLC4A2      TACC3     TPM1     FOLR2     PRRX1     THBS1
#
#           C51      C52      C53       C54      C55       C56      C57  \
# 0      TCIRG1     MMP9      VIM     EGFL7   COL4A1      AKNA    MS4A7
# 1       RUFY4     ACP5     MMP9      CDH5     CDH5    CORO1A    HSPA6
# 2        EXT1     CTSK      CKB     NPDC1    HSPG2   ARHGEF1   MS4A6A
# 3    ATP6V1B2     CST3   TMSB10    COL4A1   COL4A2   ARHGAP4    STAB1
# 4     COL27A1      CKB     ACTB    COL4A2    EGFL7       EVL    ADAP2
# 5       CLCN7      GRN      FTL     HSPG2     CD93      TMC8    CD163
# 6        ACP5     CD68   TMSB4X     MCF2L    PLVAP     CELF2     DAB2
# 7         CKB   TCIRG1     PFN1   AFAP1L1    NPDC1     ACAP1   CORO1A
# 8        JDP2     SPP1     CST3   RAPGEF5     ESAM     LENG8    CELF2
# 9      PTPN22   LAPTM5     EEF2    PECAM1   PECAM1     MYO1G   IL10RA
# 10       CTSK    ANPEP   LGALS1      FLT4    MMRN2   CCDC88C    CXCR4
# 11       MMP9      CA2     CTSK    PLXND1   IGFBP7     IKZF1     TRAC
# 12     STRIP2    IFI30   S100A4      ESAM    HYAL2    ARGLU1  SIGLEC1
# 13     NFATC1     PSAP  S100A10  ARHGAP29  AFAP1L1     NLRC5     APOE
# 14  KIDINS220     CYBA     JDP2    SHANK3     VWA1      FYB1    MPEG1
# 15       DNM1      VIM     ACP5      CD93     CD34    RASAL3  SLCO2B1
# 16      DOCK5    TIMP2     OAZ1     PLVAP    PODXL     ITGAL  SELENOP
# 17       MATK      GSN   S100A6     ROBO4    MCF2L      TRAC     C1QC
# 18      ACTN2     NPC2      CA2      PLK2      APP      DEF6     AKNA
# 19      AKAP6  ATP6AP1    HMOX1     DOCK6    ROBO4   CCDC88B     C1QA
# 20     SCARF1     CTSZ    ACTG1      DYSF   ADAM15    ATP2A3     C1QB
# 21    SLC37A2     CSTB      PKM  TNFRSF25      ENG  TRAF3IP3  TNFAIP2
# 22      FOSL2     JDP2     SPI1    PCDH17  CLEC14A     TRAF1     SAT1
# 23     SLC9B2      GNS     SPP1       KDR   PCDH17    NBEAL2    FCGRT
# 24       GIPR  ATP6V0C     CFL1     ADCY4   IGFBP4     DOCK2      EVL
# 25        SRC     CTSD   SQSTM1    ADAM15     FLT4  ARHGAP45    IL2RG
# 26       WWC1     CD63     CSTB     LAMA5   PLXND1   ARHGAP9     TMC8
# 27      CSF1R  ATP6V0B     APOE  TMEM255B  COL15A1   ZFYVE28     MRC1
# 28       TFRC      CD4      GSN      TIE1  RAPGEF5      TMC6    DOCK2
# 29   TNFRSF14     EEF2     LMNA    ARGLU1     AQP1  ARHGAP30    IKZF1
#
#         C58       C59       C60       C61       C62       C63        C64  \
# 0    COL4A2   COL18A1      TRAC      CDH5      SAT1     EGFL7      KIF22
# 1    COL4A1    COL4A1     IL2RG    COL4A1   TNFAIP2    COL4A2       SMC4
# 2     EGFL7    COL4A2      AKNA     EGFL7     MS4A7    ADAM15      NCAPG
# 3     PLVAP    PDGFRB    CORO1A    COL4A2     ITGAX     HSPG2      CENPM
# 4      CDH5    COL5A3     ITGAL     HSPG2     FCHO2      CDH5      FANCA
# 5     HYAL2    PLXDC1     ACAP1     PLVAP     GPNMB    COL4A1     NUSAP1
# 6     HSPG2    NOTCH3     IKZF1      CD93     ARAP1    PECAM1      KIFC1
# 7      CD93  CCDC102B      IL32      ESAM    MS4A6A     HYAL2     NCAPG2
# 8      ESAM    IGFBP7     SYNE2    PECAM1     FCGRT     NPDC1      TACC3
# 9    PECAM1      UACA    RASAL3   AFAP1L1      DAB2    SEMA3F  HNRNPA2B1
# 10     VWA1      MCAM   CCDC88C     MCF2L     HSPA6      CD93      FANCI
# 11  AFAP1L1      THY1      TMC8     MMRN2  TNFRSF14      ESAM        CIT
# 12    APLNR       BGN     SFRP4      FLT4     ADAP2      MCAM      TOP2A
# 13     MCAM  ARHGEF17     CXCR4      MCAM     ABCA1     MCF2L      HELLS
# 14     TIE1      JAG1       EVL      CD34     CD163   RAPGEF5       CDK1
# 15    PODXL     POSTN   OLFML2A     PODXL     CIITA   AFAP1L1       EZH2
# 16    ROBO4      VCAN    PCOLCE     NPDC1    CLEC7A     APLNR      UHRF1
# 17   PCDH17    ADGRA2     ENPP2   RAPGEF5   SIGLEC1     ROBO4       ASPM
# 18    MMRN2     CD248  SERPINF1      VWA1      GLUL     PLVAP      SYNE2
# 19  RAPGEF5    PRSS23    ATP2A3     ROBO4     RAP2B      PLK2      ESPL1
# 20   PLXND1       MGP       TNC      AQP1     CELF2       KDR      CENPI
# 21     CD34    LRRC32  TRAF3IP3     HYAL2      LGMN     ITGA6       POLE
# 22   ADGRL4      TPM1       DCN    PCDH17     ARRB2     ITGA5       ANLN
# 23     FLT4     PRKG1     TIMP3     APLNR     MYO9B     CDH13      KNTC1
# 24   ADAM15      TBX2      SUN2    SEMA3F      APOE  ADAMTSL1      MKI67
# 25    MCF2L     TAGLN    MEGF10     CLDN5    CSF2RA     TACC3  ARHGAP11A
# 26    NPDC1     EDNRA    OLFML3    IGFBP7       NPL     EPHB4       NSD2
# 27   SEMA3F     LAMA4   ANKRD44    ADAM15   SLCO2B1     MMRN2      TCF19
# 28    CLDN5   ADAMTS2      IBSP   CLEC14A     DOCK2   HSPA12B       TPX2
# 29      KDR     LOXL2      IL16  ARHGAP29    FCGR2A      FLT4      NDC80
#
#          C65       C66       C67       C68       C69
# 0      SFRP4       C1S     STAB1      MMP9      ALPL
# 1        FN1       C1R      PLTP      CST3    COL1A1
# 2        CLU   EMILIN1     FCGRT      CTSK      LRP4
# 3       NNMT      GGT5      CD14    SLC9B2     SPARC
# 4        C1R       DCN      DAB2       CKB    COL1A2
# 5      FRMD6       LUM     MPEG1      ACP5     PTPRS
# 6        C1S      CSF1      APOE      EXT1   TMEM119
# 7   SERPING1     VCAM1      C1QA  SIGLEC15      INSC
# 8   SERPINE2     EPHX1      C1QC    TCIRG1      TPM1
# 9    COL10A1  LGALS3BP   SLCO2B1    SCARF1   ADAMTS2
# 10       DCN     MMP13     MS4A7       GRN     PTGDS
# 11      BST2    CCDC80     CD163     APOBR      VCAN
# 12     CDH11     TGFBI    MS4A6A     ANPEP    COL5A1
# 13     LTBP2      RCN1   SIGLEC1      JDP2   COL13A1
# 14   OLFML2B       HGF      C1QB     RUFY4      MMP2
# 15     MXRA8    PCOLCE     ADAP2      WWC1   C1QTNF1
# 16      SDC2     LOXL1      PSAP      MATK     CDH11
# 17     VCAM1      RCL1      CD74     CLCN7       CPE
# 18     ITM2B     IFI27      CYBB    MAP2K3      CHAD
# 19    SPOCK1   TMEM119     FOLR2    NFATC1      GPC1
# 20   TNFSF10    IFNGR1   SELENOP  ATP6V1B2    FKBP10
# 21    S100A6      FBN1  TMEM176B     AKAP6  SERPINF1
# 22      LY6E  SERPING1    RNASE1   COL27A1       DPT
# 23      SOX4      ENAH     HSPA6      CD84     PTH1R
# 24  KIAA1217     FRMD6   ARHGAP4   SLC37A2     PDZD2
# 25     LTBP3     FSTL1      SAT1    STRIP2     SATB2
# 26       CFH     ENPEP       MAF    SLC4A2       CLU
# 27       BOC       B2M     CSF1R      CD68     PTPRD
# 28    S100A4      CD40      LGMN      SPP1     PRRX1
# 29   DENND2B      LIFR      SDC3       SRC    CERCAM

# %%
sc.pl.rank_genes_groups_heatmap(sc_adata_merged, use_raw=False)
sc.pl.rank_genes_groups_heatmap(sc_adata_merged, show_gene_labels=True, use_raw=False)
sc.pl.umap(sc_adata_merged, color=['leiden', 'total_counts', 'batch'],use_raw=False)
sc.pl.umap(sc_adata_merged, color=['RUNX2', 'CTSK', 'LYZ'],use_raw=False)
sc.pl.umap(sc_adata_merged, color=['CD163', 'COL12A1', 'COL1A1'],use_raw=False)

# %%
# UMAP座標
umap_data = sc_adata_merged.obsm['X_umap']


# クラスタリストをソート（C1, C2, ...）
clusters = sorted(
    sc_adata_merged.obs['leiden'].unique().tolist(),
    key=lambda x: int(x[1:])
)

# 横6列、必要な行数を計算
n_cols = 6
n_rows = math.ceil(len(clusters) / n_cols)

fig, axes = plt.subplots(n_rows, n_cols, figsize=(4 * n_cols, 4 * n_rows))

for idx, cluster in enumerate(clusters):
    row = idx // n_cols
    col = idx % n_cols
    ax = axes[row, col] if n_rows > 1 else axes[col]
    
    is_highlight = sc_adata_merged.obs['leiden'] == cluster
    
    # 灰色（他クラスタ）
    ax.scatter(
        umap_data[~is_highlight, 0],
        umap_data[~is_highlight, 1],
        color='lightgrey',
        s=10,
        alpha=0.3
    )
    
    # 赤（対象クラスタ）
    ax.scatter(
        umap_data[is_highlight, 0],
        umap_data[is_highlight, 1],
        color='red',
        s=10,
        alpha=0.6
    )
    
    ax.set_title(f"{cluster}")
    ax.set_xlabel('UMAP1')
    ax.set_ylabel('UMAP2')

# 余った空白プロットを消す
for j in range(len(clusters), n_rows * n_cols):
    row = j // n_cols
    col = j % n_cols
    ax = axes[row, col] if n_rows > 1 else axes[col]
    ax.axis('off')

plt.tight_layout()
plt.show()

# %%
annotation_dict = {
    'C0':  'Tumor',
    'C1':  'Tumor',
    'C2':  'Tumor',
    'C3':  'Tumor',
    'C4':  'Tumor',
    'C5':  'Tumor',
    'C6':  'Tumor',
    'C7':  'Tumor',
    'C8':  'Tumor',
    'C9':  'Tumor',
    'C10': 'Tumor',
    'C11': 'Tumor',
    'C12': 'Tumor',
    'C13': 'Tumor',
    'C14': 'Tumor',
    'C15': 'Tumor',
    'C16': 'Tumor',
    'C17': 'Tumor',
    'C18': 'Tumor',
    'C19': 'Tumor',
    'C20': 'Monocyte',
    'C21': 'Monocyte',
    'C22': 'Tumor',
    'C23': 'Tumor',
    'C24': 'Doublet',
    'C25': 'Doublet',
    'C26': 'Lymphocyte',
    'C27': 'Doublet',
    'C28': 'Lymphocyte',
    'C29': 'Doublet',
    'C30': 'Doublet',
    'C31': 'Doublet',
    'C32': 'Monocyte',
    'C33': 'Monocyte',
    'C34': 'Monocyte',
    'C35': 'Tumor',
    'C36': 'Tumor',
    'C37': 'Monocyte',
    'C38': 'Monocyte',
    'C39': 'Monocyte',
    'C40': 'Monocyte',
    'C41': 'Tumor',
    'C42': 'Tumor',
    'C43': 'Tumor',
    'C44': 'GiantCell',
    'C45': 'Doublet',
    'C46': 'GC_proliferating',
    'C47': 'Tumor',
    'C48': 'Doublet',
    'C49': 'CAFibroblast',
    'C50': 'Tumor',
    'C51': 'GiantCell',
    'C52': 'GiantCell',
    'C53': 'Doublet',
    'C54': 'Endothelial',
    'C55': 'Endothelial',
    'C56': 'Doublet',
    'C57': 'Monocyte',
    'C58': 'Doublet',
    'C59': 'CAFibroblast',
    'C60': 'Tumor',
    'C61': 'Doublet',
    'C62': 'Monocyte',
    'C63': 'Endothelial',
    'C64': 'Doublet',
    'C65': 'Tumor',
    'C66': 'Tumor',
    'C67': 'Monocyte',
    'C68': 'GiantCell',
    'C69': 'Doublet',
}

# %%
sc_adata_merged.obs['cell_type'] = [annotation_dict[clust] for clust in sc_adata_merged.obs['leiden']]
# Doublet removed
filtered_sc_adata = sc_adata_merged[~sc_adata_merged.obs['cell_type'].isin(['Doublet', 'Other'])].copy()
sc.pl.umap(filtered_sc_adata, color=['leiden'])
sc.pl.umap(filtered_sc_adata, color=['cell_type'])
#filtered_sc_adata.obs['cell_type_annotation'] = filtered_sc_adata.obs['cell_type']
filtered_sc_adata.obs['cell_type_annotation'] = filtered_sc_adata.obs['leiden']
# Save results for label transfering
filtered_sc_adata.write_h5ad(h5ad_sc_filtered_full_save_path)

# %%
sc.tl.dendrogram(filtered_sc_adata, groupby='cell_type')
sc.tl.rank_genes_groups(filtered_sc_adata, 'cell_type', method='wilcoxon', use_raw=False)
sc.pl.rank_genes_groups_heatmap(filtered_sc_adata, use_raw=False)
sc.pl.rank_genes_groups_heatmap(filtered_sc_adata, show_gene_labels=True, use_raw=False)

# %%
sc.pl.umap(filtered_sc_adata, color=['leiden', 'total_counts', 'batch'],use_raw=False)
sc.pl.umap(filtered_sc_adata, color=['TRAC', 'CTSK', 'LYZ'],use_raw=False)		
sc.pl.umap(filtered_sc_adata, color=['IL2RG', 'AKNA', 'IL32'],use_raw=False)
sc.pl.umap(filtered_sc_adata, color=['CORO1A', 'CCNL2', 'LENG8'],use_raw=False)
